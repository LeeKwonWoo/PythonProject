# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# window에서 한글 출력해주는 코드
from matplotlib import font_manager,rc
font_name = font_manager.FontProperties(fname="c:\Windows\Fonts\malgun.ttf").get_name()
rc('font',family = font_name)
from numpy.random import randn
from pandas import DataFrame

# %%
plt.title("Test")
plt.plot([1,2,3,4,5,6,7,8,9])
plt.show()

# %%
plt.title("TEST")
plt.plot([1,2,3,4,5,6,7])
plt.plot([3,6,9,12])
plt.plot([6,7,8,9])
plt.show()

# %%
fig = plt.figure()
graph = fig.add_subplot(1,1,1)
graph = graph.plot(randn(50),cumsum(),'k--')
#add_subplot (row 수, colum수, ?)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c012ba795f26> in <module>
#       1 fig = plt.figure()
#       2 graph = fig.add_subplot(1,1,1)
# ----> 3 graph = graph.plot(randn(50),cumsum(),'k--')
#       4 #add_subplot (row 수, colum수, ?)
#
# NameError: name 'cumsum' is not defined
