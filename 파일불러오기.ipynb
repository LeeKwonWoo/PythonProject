# %%
# 파이썬 파일 불러오기
# %run py/Two.py
# Out:
# 1. 문자열 연습입니다.
# ...
# 2. 문자열 연습입니다.
# ...
# 3. 문자열
#        연습
#        입니다.
# ...
# 4. "문자열"
# 연습
# 입니다.
# ...
# 5. 문자열
# 연습
# 입니다.
# ...
#
#
#
#
#
#
# my_string
#
#
# 안녕하세요? 제이름은   파이썬이고  20세 입니다.
# 안녕하세요? 제이름은  파이썬이고  20 세 입니다.
# 안녕하세요? 제이름은
#  파이썬이고  20세 입니다.
#
#
# =====
#
#
# my_string
# ...
# messagemessagemessage
# 가격은 20000원 입니다.

# %%
num = 7
if num % 2 :
    print('참')
else :
    print('거짓')
# Out:
# 참

# %%
# 이미지 불러오기
from IPython.display import Image
Image('img\sm.png') # / == \

# %%
#
